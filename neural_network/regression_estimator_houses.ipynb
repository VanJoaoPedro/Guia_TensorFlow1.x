# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.compat.v1 as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
tf.disable_control_flow_v2
# Out:
# <function tensorflow.python.ops.control_flow_v2_toggles.disable_control_flow_v2>

# %%
base = pd.read_csv('/content/drive/My Drive/TensorFlow_1.x_guide/neural_network/CSV/house_prices.csv')
base.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
base.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
used_columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long']
used_columns
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long']

# %%
base = pd.read_csv('/content/drive/My Drive/TensorFlow_1.x_guide/neural_network/CSV/house_prices.csv', usecols=used_columns)
base.head()
# Out:
#       price  bedrooms  bathrooms  ...  zipcode      lat     long
# 0  221900.0         3       1.00  ...    98178  47.5112 -122.257
# 1  538000.0         3       2.25  ...    98125  47.7210 -122.319
# 2  180000.0         2       1.00  ...    98028  47.7379 -122.233
# 3  604000.0         4       3.00  ...    98136  47.5208 -122.393
# 4  510000.0         3       2.00  ...    98074  47.6168 -122.045
#
# [5 rows x 17 columns]

# %%
scaler_X = MinMaxScaler()
base[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long']] = scaler_X.fit_transform(base[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long']])

# %%
base.head()
# Out:
#       price  bedrooms  bathrooms  ...   zipcode       lat      long
# 0  221900.0  0.090909    0.12500  ...  0.893939  0.571498  0.217608
# 1  538000.0  0.090909    0.28125  ...  0.626263  0.908959  0.166113
# 2  180000.0  0.060606    0.12500  ...  0.136364  0.936143  0.237542
# 3  604000.0  0.121212    0.37500  ...  0.681818  0.586939  0.104651
# 4  510000.0  0.090909    0.25000  ...  0.368687  0.741354  0.393688
#
# [5 rows x 17 columns]

# %%
scaler_y = MinMaxScaler()
base[['price']] = scaler_y.fit_transform(base[['price']])
base.head()
# Out:
#       price  bedrooms  bathrooms  ...   zipcode       lat      long
# 0  0.019266  0.090909    0.12500  ...  0.893939  0.571498  0.217608
# 1  0.060721  0.090909    0.28125  ...  0.626263  0.908959  0.166113
# 2  0.013770  0.060606    0.12500  ...  0.136364  0.936143  0.237542
# 3  0.069377  0.121212    0.37500  ...  0.681818  0.586939  0.104651
# 4  0.057049  0.090909    0.25000  ...  0.368687  0.741354  0.393688
#
# [5 rows x 17 columns]

# %%
X = base.drop('price', axis=1)
y = base.price

# %%
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...   zipcode       lat      long
# 0  0.090909    0.12500     0.067170  ...  0.893939  0.571498  0.217608
# 1  0.090909    0.28125     0.172075  ...  0.626263  0.908959  0.166113
# 2  0.060606    0.12500     0.036226  ...  0.136364  0.936143  0.237542
# 3  0.121212    0.37500     0.126038  ...  0.681818  0.586939  0.104651
# 4  0.090909    0.25000     0.104906  ...  0.368687  0.741354  0.393688
#
# [5 rows x 16 columns]

# %%
y.head()
# Out:
# 0    0.019266
# 1    0.060721
# 2    0.013770
# 3    0.069377
# 4    0.057049
# Name: price, dtype: float64

# %%
predict_columns = used_columns[1:17]
predict_columns
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long']

# %%
columns = [tf.feature_column.numeric_column(key=c) for c in predict_columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train.shape
# Out:
# (15129, 16)

# %%
X_test.shape
# Out:
# (6484, 16)

# %%
function_train = tf.estimator.inputs.pandas_input_fn(x = X_train, y = y_train, batch_size=32, num_epochs=None, shuffle=True)
regressor = tf.estimator.DNNRegressor(hidden_units=[8, 8, 8], feature_columns=columns)
regressor.train(input_fn=function_train, steps=20000)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/lazy_loader.py:63: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpso0aprs1
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpso0aprs1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
function_prevision = tf.estimator.inputs.pandas_input_fn(x = X_test, shuffle=False)
prevision = regressor.predict(input_fn=function_prevision)
list(prevision)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpso0aprs1/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ...

# %%
val_prevision = []
for p in regressor.predict(input_fn=function_prevision):
  val_prevision.append(p['predictions'][0])
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer dnn is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpso0aprs1/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
val_prevision
# Out:
# [0.080164015,
#  0.041772768,
#  0.030012626,
#  0.06356175,
#  0.024304789,
#  0.049064666,
#  0.07039892,
#  0.0678276,
#  0.024304789,
#  0.024304789,
#  0.08424905,
#  0.04387732,
#  0.035416327,
#  0.039933015,
#  0.024198107,
#  0.04744921,
#  0.08965549,
#  0.09318225,
#  0.026766576,
#  0.03295413,
#  0.087422796,
#  0.04758624,
#  0.101090275,
#  0.059422992,
#  0.033402372,
#  0.19937027,
#  0.04481876,
#  0.064694405,
#  0.06231261,
#  0.024304789,
#  0.061077856,
#  0.048196055,
#  0.045377977,
#  0.07485804,
#  0.024304789,
#  0.057136767,
#  0.15407489,
#  0.08256027,
#  0.07621591,
#  0.048173435,
#  0.061667696,
#  0.039180085,
#  0.023762628,
#  0.052617922,
#  0.13681176,
#  0.037899632,
#  0.042853758,
#  0.04491783,
#  0.19728339,
#  0.038744085,
#  0.024304789,
#  0.09454819,
#  0.038751677,
#  0.025202285,
#  0.042257156,
#  0.19163951,
#  0.04089812,
#  0.024304789,
#  0.049767904,
#  0.040561523,
#  0.047549024,
#  0.042296864,
#  0.037848115,
#  0.024304789,
# ...

# %%
val_prevision = np.asarray(val_prevision).reshape(-1,1)
val_prevision = scaler_y.inverse_transform(val_prevision)
val_prevision
# Out:
# array([[686250.6 ],
#        [393517.38],
#        [303846.28],
#        ...,
#        [471139.16],
#        [477001.38],
#        [581783.06]], dtype=float32)

# %%
y_test2 = y_test.values.reshape(-1, 1)
y_test2 = scaler_y.inverse_transform(y_test2)
y_test2
# Out:
# array([[354000.],
#        [319500.],
#        [270000.],
#        ...,
#        [464000.],
#        [420000.],
#        [313100.]])

# %%
mae = mean_absolute_error(y_test2, val_prevision)
mae
# Out:
# 107472.15925981262
